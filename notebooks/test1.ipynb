# %%
import networkx as nx

# %%
G0 = nx.read_gml('/home/paolo/Projects/pm_networks/graphml/penthouse_00.gml')

# %%
import matplotlib.pyplot as plt

# %%
nx.draw(G0)

# %%
G1 = nx.read_gml('/home/paolo/Projects/pm_networks/graphml/penthouse_01.gml')

# %%
nx.draw(G1)

# %%
G2 = nx.read_gml('/home/paolo/Projects/pm_networks/graphml/penthouse_02.gml')

# %%
nx.draw(G2)
